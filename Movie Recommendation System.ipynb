# %%
#Movie Recommendation System
#Introduction
#This project is a simple Python-based Movie Recommendation System. It asks the choice to select a preferred movie genre and then suggests movies from that genre. It uses fundamental Python concepts like lists and conditional statements (if-else-elif).
#Requirements
#- Python installed on your system
#- Basic knowledge of Python programming (if-else, lists, loops)

print(" 1 = Action \n 2 = Thriller \n 3 = Comedy \n 4 = adventure \n 5 = war \n 6 = kids \n 7 = horror \n 8 = drama \n 9 = romance \n \n")

choice = input("Enter the genre:")

action = ["James Bond, Mission Impossible, The Bourne, Hitman, The Expendables, John Wick, Fast & Furious"]

thriller = ["Se7en, Zodiac, Prisoners, Gone Girl, Shutter Island, The Sixth Sense, The Departed, The Prestige"]

comedy = ["Johnny English, Bad Boys, The Hangover, Due Date, Ride Along, 21 and Over, Central Intelligence"]

adventure = ["Harry Potter, Jurassic Park, Avatar, The Lord of the Rings, Pirates of the Caribbean, Jumanji"]

war = ["Saving Private Ryan, 1917, Hacksaw Ridge, Greyhound, Operation Mincemeat, All Quiet On The Western Front"]

kids = ["Toy Story, Finding Nemo, Frozen, The Lion King, Moana, Ice Age, Hotel Transylvania, Despicable Me"]

horror = ["The Conjuring, It, Hereditary, The Exorcist, A Quiet Place, The Quiet Place, Annabelle, Insidious"]

drama = ["About Time, The Green Mile, Whiplash, A Beautiful Mind, The Pursuit of Happyness, Good Will Hunting"]

romance = ["The Notebook, Pride and Prejudice, La La Land, A Walk to Remember, Before Sunrise, Call Me by Your Name"]

if choice == "1":
    for movie in action :
      print(f"-{action}")

elif choice == "2":
    for movie in thriller :
     print(f"-{thriller}")

elif choice == "3":
    for movie in comedy :
     print(f"-{comedy}")

elif choice == "4":
    for movie in adventure :
     print(f"-{adventure}")

elif choice == "5":
    for movie in war :
     print(f"-{war}")

elif choice == "6":
    for movie in kids :
     print(f"-{kids}")

elif choice == "7":
    for movie in horror:
       print(f"-{horror}")

elif choice == "8":
    for movie in drama:
     print(f"-{drama}")

elif choice == "9":
    for movie in romance:
     print(f"-{romance}")

else :
     print("Error")
# Out:
#  1 = Action
#  2 = Thriller
#  3 = Comedy
#  4 = adventure
#  5 = war
#  6 = kids
#  7 = horror
#  8 = drama
#  9 = romance
#
#
# -['Harry Potter, Jurassic Park, Avatar, The Lord of the Rings, Pirates of the Caribbean, Jumanji']
