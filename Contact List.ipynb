# %%
# Contact Book

def contact_book():
    contacts = {}

    while True:
        print("\nContact Book :")
        print("1. Add/Create Contact")
        print("2. View Contacts")
        print("3. Search Contact")
        print("4. Exit")

        choice = input("Enter Input (1-4): ")

        if choice == '1':
            name = input("Enter Name: ")
            phone = input("Enter Number: ")
            contacts[name] = phone
            print("Contact Added.")

        elif choice == '2':
            print("\nContacts List:")
            if contacts:
                for name, phone in contacts.items():
                    print(f"{name}: {phone}")
            else:
                print("No contacts found.")

        elif choice == '3':
            search_name = input("Enter name to search: ")
            if search_name in contacts:
                print(f"{search_name}: {contacts[search_name]}")
            else:
                print("Contact not found.")

        elif choice == '4':
            print("Exiting Contact Book.")
            break

        else:
            print("Invalid Input. Please enter a number from 1 to 4.")

contact_book()
# Out:
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Contact Added.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
#
# Contacts List:
# krish: 8989
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# krish: 8989
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Contact Added.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
#
# Contacts List:
# krish: 8989
# vraj: 121212
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Invalid Input. Please enter a number from 1 to 4.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Invalid Input. Please enter a number from 1 to 4.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Invalid Input. Please enter a number from 1 to 4.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Invalid Input. Please enter a number from 1 to 4.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Invalid Input. Please enter a number from 1 to 4.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Exiting Contact Book.

# %%
contact_book()
# Out:
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Contact Added.
#
# Contact Book :
# 1. Add/Create Contact
# 2. View Contacts
# 3. Search Contact
# 4. Exit
# Exiting Contact Book.
